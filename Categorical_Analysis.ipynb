# %%
import seaborn as sns
import pandas as pd
df=sns.load_dataset('taxis')
print(df.head())
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
(df.shape[0]-df.dropna().shape[0])
# Out:
# 92

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 1.4301259132597544

# %%
df.dropna()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6341 rows x 14 columns]

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df=df.reset_index(drop=True)

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %% [markdown]
# EDA

# %%
#tip is numerical feature,analyse with color feature with categorical
df.tip.value_counts()
# Out:
# tip
# 0.00     2244
# 1.00      312
# 2.00      211
# 2.16       89
# 1.86       79
#          ...
# 11.00       1
# 10.30       1
# 8.89        1
# 5.07        1
# 6.65        1
# Name: count, Length: 481, dtype: int64

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
#graphical analysis of categorical
sns.barplot(x='color',y='tip',data=df,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x='color',y='tip',data=df,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

sns.histplot(x=df.tip,hue=df.color,kde=True,palette=['yellow', 'green'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# **Hypotheses:**
# - H0: distribution of tip for yellow = distribution of tip of green
# - H1:distribution of tip for yellow != distribution of tip of green

# %%
yellow_tip = df['tip'][df['color']=='yellow']
green_tip = df['tip'][df['color']=='green']
print(yellow_tip)
print(green_tip)
# Out:
# 0       2.15
# 1       0.00
# 2       2.36
# 3       6.15
# 4       1.10
#         ...
# 5446    2.66
# 5447    2.36
# 5448    2.56
# 5449    2.36
# 5450    1.33
# Name: tip, Length: 5373, dtype: float64
# 5451    0.00
# 5452    0.00
# 5453    1.20
# 5454    0.00
# 5455    0.00
#         ...
# 6428    1.06
# 6429    0.00
# 6430    0.00
# 6431    0.00
# 6432    3.36
# Name: tip, Length: 968, dtype: float64

# %%
# Independent T-Test
from scipy import stats

t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# P-value: 7.791088119489451e-64

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis: the tip for yellow category is different that of green")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis: the tip for yellow category is different that of green

# %%
#tip is numerical feature,analyse with payment feature with categorical
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1,3, figsize=(15,4))
sns.barplot(x='payment', y='tip', data=df, estimator='mean', ax=axes[0])
axes[0].set_title("Mean Tip")
sns.barplot(x='payment', y='tip', data=df, estimator='std', ax=axes[1])
axes[1].set_title("Std Tip")

sns.histplot(data=df, x='tip', hue='payment', kde=True, ax=axes[2])
axes[2].set_title("Histogram")

plt.tight_layout()
plt.show()

# %% [markdown]
# Hypotheses:
#
# H0: distribution of tip for credit card= distribution of tip of cash
# H1:distribution of tip for credit card != distribution of tip of cash

# %%
credit_tip = df['tip'][df['payment']=='credit card']
cash_tip = df['tip'][df['payment']=='cash']

# %%
# Independent T-Test
from scipy import stats

t_stat, p_val = stats.ttest_ind(credit_tip, cash_tip)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# P-value: 0.0

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis: the tip for credit card payment category is different that of cash ")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis: the tip for credit card payment category is different that of cash

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'], palette='Set2') #univariant
# Out:
# /tmp/ipython-input-3733200601.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'], palette='Set2') #univariant
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2')
# Out:
# /tmp/ipython-input-483514082.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='mean')
# Out:
# /tmp/ipython-input-2605922404.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='mean')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='std')
# Out:
# /tmp/ipython-input-1597738132.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'], y=df['tip'], palette='Set2',estimator='std')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot  (x=df['tip'], hue=df['pickup_borough'], kde=True,bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# **hypothesis**
#
# h0 : distribution of tip is the same across all pickup_borough categories
#
# h1 : at least one category has a different distribution of *tip*

# %%
from scipy import stats

# Separate tip values by borough
manhattan_tip = df.loc[df['pickup_borough'] == 'Manhattan', 'tip']
queens_tip    = df.loc[df['pickup_borough'] == 'Queens', 'tip']
bronx_tip     = df.loc[df['pickup_borough'] == 'Bronx', 'tip']
brooklyn_tip  = df.loc[df['pickup_borough'] == 'Brooklyn', 'tip']

# %%
# One-way ANOVA
f_stat, p_val = stats.f_oneway(
    manhattan_tip,
    queens_tip,
    bronx_tip,
    brooklyn_tip
)

print('F-statistic:', f_stat)
print('p-value:', p_val)
# Out:
# F-statistic: 91.5793383185057
# p-value: 5.155109332422435e-58

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %% [markdown]
# Hypotheses (for each pair of boroughs):
#
# H0: Distribution (mean tip) of group1 = distribution of group2
#
# H1: Distribution (mean tip) of group1 ≠ distribution of group2

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey HSD test
tukey_result = pairwise_tukeyhsd(
    endog=df['tip'],
    groups=df['pickup_borough'],
    alpha=0.05
)

# Print results
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
df['dropoff_borough'].unique()
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sns.countplot(
    x='dropoff_borough',
    hue='dropoff_borough',
    data=df,
    palette='Set2',
    legend=False
)
plt.title("Count of Dropoffs by Borough")
plt.show()

# %%
sns.barplot(
    x='dropoff_borough',
    y='tip',
    hue='dropoff_borough',
    data=df,
    palette='Set2',
    estimator='mean',
    legend=False
)
plt.title("Mean Tip by Dropoff Borough")
plt.show()

# %%
sns.barplot(
    x='dropoff_borough',
    y='tip',
    hue='dropoff_borough',
    data=df,
    palette='Set2',
    estimator='std',
    legend=False
)
plt.title("Tip Standard Deviation by Dropoff Borough")
plt.show()

# %%
df.groupby('dropoff_borough')['tip'].mean()
df.groupby('dropoff_borough')['tip'].std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
sns.histplot(
    data=df,
    x='tip',
    hue='dropoff_borough',
    kde=True,
    bins=30
)
plt.title("Tip Distribution by Dropoff Borough")
plt.show()

# %% [markdown]
# Hypotheses
#
# H₀: Mean tip is the same across all dropoff boroughs
#
# H₁: At least one dropoff borough has a different mean tip

# %%
from scipy import stats

# Create list of tip arrays by dropoff borough
categories = [
    group['tip'].dropna().values
    for _, group in df.groupby('dropoff_borough')
]

# One-way ANOVA (use * to unpack)
f_stat, p_val = stats.f_oneway(*categories)

print("F-statistic:", f_stat)
print("p-value:", p_val)
# Out:
# F-statistic: 31.42417796696828
# p-value: 5.87859571331583e-26

# %%
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %%
alpha = 0.05

if p_val < alpha:
    print("Reject H0: Mean tips differ by dropoff borough.\n")

    tukey_result = pairwise_tukeyhsd(
        endog=df['tip'],
        groups=df['dropoff_borough'],
        alpha=alpha
    )
    print(tukey_result)

else:
    print("Fail to reject H0: No significant difference in mean tips.")
# Out:
# Reject H0: Mean tips differ by dropoff borough.
#
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
from scipy import stats


categories = [
    group['tip'].dropna().values
    for _, group in df.groupby('pickup_zone')
]

# One-way ANOVA (use * to unpack)
f_stat, p_val = stats.f_oneway(*categories)

print("F-statistic:", f_stat)
print("p-value:", p_val)
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# F-statistic: 7.563376210961916
# p-value: 7.892434822136223e-169
# Reject null hypothesis

# %%
from scipy import stats


categories = [
    group['tip'].dropna().values
    for _, group in df.groupby('dropoff_zone')
]

# One-way ANOVA (use * to unpack)
f_stat, p_val = stats.f_oneway(*categories)

print("F-statistic:", f_stat)
print("p-value:", p_val)
alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# F-statistic: 5.76903467327541
# p-value: 1.3107168403745948e-120
# Reject null hypothesis

# %%
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
sns.histplot(df['passengers'],kde=True)
plt.show()

# %%
sns.histplot(df['fare'],kde=True)
plt.show()

# %%
sns.histplot(df['distance'],kde=True)
plt.show()

# %%
sns.histplot(df['total'],kde=True)
plt.show()

# %%
sns.histplot(df['tolls'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.tolls)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.fare)
plt.show()

# %% [markdown]
# Pearson Correlation Test
#
#  Hypotheses:
#
# H0 (Null Hypothesis): Correlation between tip and fare is zero
#                     (ρ = 0)
#
#
# H1 (Alternative Hypothesis): Correlation between tip and fare is not zero
#                            (ρ ≠ 0)

# %%
df.passengers.skew()
# Out:
# np.float64(2.349366327837006)

# %%
df.passengers.kurtosis()
# Out:
# np.float64(4.8167003036423175)

# %%
# Compute Pearson correlation
r, p_val = stats.spearmanr(df['tip'], df['passengers'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.027509812818779178
# P-value: 0.028480753176042872
# Reject null hypothesis: Significant correlation exists.

# %%
r, p_val = stats.spearmanr(df['tip'], df['passengers'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.027509812818779178
# P-value: 0.028480753176042872
# Reject null hypothesis: there is no relationship.

# %%
df.fare.skew()
# Out:
# np.float64(2.606558389580325)

# %%
df.fare.kurtosis()
# Out:
# np.float64(10.170827993181963)

# %%
r, p_val = stats.spearmanr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.310254279563729
# P-value: 1.5556730728881364e-141
# Reject null hypothesis: there is no relationship.

# %%
# Compute Pearson correlation
r, p_val = stats.pearsonr(df['tip'], df['fare'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: Significant correlation exists.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.48710089077355956
# P-value: 0.0
# Reject null hypothesis: Significant correlation exists.

# %%
r, p_val = stats.spearmanr(df['tip'], df['tolls'])

print("Correlation coefficient (r):", r)
print("P-value:", p_val)

# Significance level
alpha = 0.05

# Decision rule
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
# Out:
# Correlation coefficient (r): 0.175380002891528
# P-value: 5.643276180955435e-45
# Reject null hypothesis: there is no relationship.

# %%
nm=df[['fare','tip','tolls','distance','passengers']]

# %%
sns.heatmap(nm.corr(),annot=True,cmap="Blues")
plt.show()

# %%
import seaborn as sns
import pandas as pd
df=sns.load_dataset('taxis')
#df=df.dropna()
#df=df.reset_index(drop=True)

df['pickup_month']=df['pickup'].dt.month_name()
df['pickup_year']=df['pickup'].dt.year
df['pickup_day']=df['pickup'].dt.day
df['pickup_hour'] = df['pickup'].dt.hour
df['pickup_day_name']=df['pickup'].dt.day_name()
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
# 3         Yorkville West      Manhattan       Manhattan        March
# 4         Yorkville West      Manhattan       Manhattan        March
#
#    pickup_year  pickup_day  pickup_hour pickup_day_name
# 0         2019          23           20        Saturday
# 1         2019           4           16          Monday
# 2         2019          27           17       Wednesday
# 3         2019          10            1          Sunday
# 4         2019          30           13        Saturday

# %%
#sns.barplot(x=df['pickup_month'], y=df['tip'], palette='Set2')
df.pickup_month.value_counts()
# Independent T-Test
from scipy import stats
march_tip=df['tip'][df['pickup_month']=='March']
feb_tip=df['tip'][df['pickup_month']=='February']
t_stat, p_val = stats.ttest_ind(march_tip,feb_tip)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
#Fail to reject null hypothesis No significant correleation.
#So we have to delete that column.
#df.drop('pickup_month',axis=1)
# Out:
# P-value: 0.4189126749087557
# Fail to reject null hypothesis: No significant correlation.

# %%
import pandas as pd
df.pickup_day.value_counts()
df.pickup_day.skew()
df.pickup_day.kurtosis()
sns.countplot(x=df['pickup_day_name'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('pickup_day_name')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs in days")
else:
    print("Fail to reject null hypothesis: No significant difference in days")

#df.drop('pickup_day_name',axis=1)
# Out:
# ANOVA F-statistic: 1.4471639701962755
# P-value: 0.1924013537505429
# Fail to reject null hypothesis: No significant difference in days

# %%
sns.countplot(x=df['pickup_day_name'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('pickup_day_name')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs in days")
else:
    print("Fail to reject null hypothesis: No significant difference in days")
# Out:
# ANOVA F-statistic: 1.4471639701962755
# P-value: 0.1924013537505429
# Fail to reject null hypothesis: No significant difference in days

# %%
r,p_val=stats.pearsonr(df['tip'],df['pickup_hour'])
print("pearson's rank correlation coefficient:", r)
print("P-value:", p_val)
if p_val<0.005:
  print("Reject null hypothesis: there is significant correlation")
else:
  print("Fail to reject null hypothesis: there is no significant correlation")
# Out:
# pearson's rank correlation coefficient: 0.03254855228845337
# P-value: 0.009033781698873393
# Fail to reject null hypothesis: there is no significant correlation

# %%
df.pickup_year.value_counts()
# Out:
# pickup_year
# 2019    6433
# Name: count, dtype: int64

# %%
import seaborn as sns
import pandas as pd
df=sns.load_dataset('taxis')
#df=df.dropna()
#df=df.reset_index(drop=True)

df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_day']=df['dropoff'].dt.day
df['dropoff_hour'] = df['dropoff'].dt.hour
df['dropoff_day_name']=df['dropoff'].dt.day_name()
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough dropoff_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan         March
# 1  Upper West Side South      Manhattan       Manhattan         March
# 2           West Village      Manhattan       Manhattan         March
# 3         Yorkville West      Manhattan       Manhattan         March
# 4         Yorkville West      Manhattan       Manhattan         March
#
#    dropoff_year  dropoff_day  dropoff_hour dropoff_day_name
# 0          2019           23            20         Saturday
# 1          2019            4            16           Monday
# 2          2019           27            18        Wednesday
# 3          2019           10             1           Sunday
# 4          2019           30            13         Saturday

# %%
df.shape
# Out:
# (6433, 19)

# %%
#sns.barplot(x=df['pickup_month'], y=df['tip'], palette='Set2')
df.dropoff_month.value_counts()
# Independent T-Test
from scipy import stats
march_tip=df['tip'][df['dropoff_month']=='March']
feb_tip=df['tip'][df['dropoff_month']=='February']
t_stat, p_val = stats.ttest_ind(march_tip,feb_tip)
#print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
alpha=0.05
if p_val < alpha:
    print("Reject null hypothesis: there is no relationship.")
else:
    print("Fail to reject null hypothesis: No significant correlation.")
#Fail to reject null hypothesis No significant correleation.
#So we have to delete that column.
#df.drop('dropoff_month',axis=1)
# Out:
# P-value: 0.4188528837206571
# Fail to reject null hypothesis: No significant correlation.

# %%
import pandas as pd
df.dropoff_day.value_counts()
df.dropoff_day.skew()
df.dropoff_day.kurtosis()
sns.countplot(x=df['dropoff_day_name'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('dropoff_day_name')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs in days")
else:
    print("Fail to reject null hypothesis: No significant difference in days")

#df.drop('pickup_day_name',axis=1)
# Out:
# ANOVA F-statistic: 1.3952839146184404
# P-value: 0.21230581660212697
# Fail to reject null hypothesis: No significant difference in days

# %%
r,p_val=stats.pearsonr(df['tip'],df['dropoff_hour'])
print("pearson's rank correlation coefficient:", r)
print("P-value:", p_val)
if p_val<0.005:
  print("Reject null hypothesis: there is significant correlation")
else:
  print("Fail to reject null hypothesis: there is no significant correlation")
# Out:
# pearson's rank correlation coefficient: 0.03809810593015923
# P-value: 0.002241528703838599
# Reject null hypothesis: there is significant correlation

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total  color  payment  pickup_zone  dropoff_zone  pickup_borough  \
# 0    0.0  12.95      1        1           99           176               2
# 1    0.0   9.30      1        0          174           182               2
# 2    0.0  14.16      1        1            1           190               2
# 3    0.0  36.95      1        1           86           202               2
# 4    0.0  13.40      1        1          116           202               2
#
#    dropoff_borough dropoff_month  dropoff_year  dropoff_day  dropoff_hour  \
# 0                2         March          2019           23            20
# 1                2         March          2019            4            16
# 2                2         March          2019           27            18
# 3                2         March          2019           10             1
# 4                2         March          2019           30            13
#
#   dropoff_day_name
# 0         Saturday
# 1           Monday
# 2        Wednesday
# 3           Sunday
# 4         Saturday

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# Ensure df is cleaned and all necessary time-based features are present before encoding
# Re-apply dropna and reset_index, as df was reloaded in a previous cell
df = df.dropna()
df = df.reset_index(drop=True)

# Re-create pickup-related datetime features, as they were lost from df when reloaded in a previous cell
df['pickup_month']=df['pickup'].dt.month_name()
df['pickup_year']=df['pickup'].dt.year
df['pickup_day']=df['pickup'].dt.day
df['pickup_hour'] = df['pickup'].dt.hour
df['pickup_day_name']=df['pickup'].dt.day_name()

# Re-create dropoff-related datetime features, to ensure consistency with the cleaned df
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_day']=df['dropoff'].dt.day
df['dropoff_hour'] = df['dropoff'].dt.hour
df['dropoff_day_name']=df['dropoff'].dt.day_name()

# Now, define all categorical columns that are strings and need encoding
cat=['color','payment','pickup_zone','dropoff_zone','pickup_borough','dropoff_borough','pickup_day_name','dropoff_day_name', 'pickup_month', 'dropoff_month']
for i in cat:
  df[i]=lb.fit_transform(df[i])

# %%
x=df.drop(['tip', 'pickup', 'dropoff'], axis=1)
y=df.tip
print(x.shape)
print(y.shape)
# Out:
# (6341, 21)
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('X trian shape:',x_train.shape)
print('y test shape:',y_test.shape)
print('x test shape',x_test.shape)
print('y train shape:',y_train.shape)
# Out:
# X trian shape: (5072, 21)
# y test shape: (1269,)
# x test shape (1269, 21)
# y train shape: (5072,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
print(model.coef_)
print(model.intercept_)
from sklearn.metrics import r2_score
y_train_pred=model.predict(x_train)
train_score=r2_score(y_train,y_train_pred)
print("model traing score: ",train_score)
y_test_pred=model.predict(x_test)
test_score=r2_score(y_test,y_test_pred)
print("model testing score: ",test_score)

from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
mse=mean_squared_error(y_train,y_train_pred)
print("mean squared error: ",mse)
print("root mean squared error: ",np.sqrt(mse))
mae=mean_absolute_error(y_train,y_train_pred)
print("mean absolute error: ",mae)
mape=mean_absolute_percentage_error(y_train,y_train_pred)
print("mean absolute percentage error: ",mape)

# %%
from sklearn.metrics import root_mean_squared_error,mean_squared_error,mean_absolute_error,r2_score
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.6547884281092967

# %%
mean_squared_error(y_train,y_train_pred )
# Out:
# 0.4287478855858436

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.4388063052916789
